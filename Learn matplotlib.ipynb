# %% [markdown]
# <h1 style = "color:royalblue;text-align:center;">Learn Matplotlib(Math Intuitively)</h1>
# <h3 style = "color:skyblue;text-align:right;"><span style = "color:red;">"</span> as a math lover, learning to code for adding elegance to static plots(like geogebra)<span style = "color:red;">"</span></h3>

# %% [markdown]
# <p align="left">
#   <img src="https://upload.wikimedia.org/wikipedia/commons/8/84/Matplotlib_icon.svg" alt="Matplotlib Logo" width="100">
# </p>

# %% [markdown]
# <h2 style = color:#369006;>General Template: <span style = color:#FE9900;>Coordinate Style 2D Graph</span></h2>

# %% [markdown]
# ## 🗺️ Notebook Map
# - 📌 Step-by-step function plotting
# - 🎨 Styling for elegance
# - 🎓 Mathematical interpretations
# - 🧠 Reflection on visual teaching

# %% [markdown]
# <h3 style = color:#060270;>Example(1)</h3>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Define domain
x = np.linspace(-4 * np.pi, 4 * np.pi, 800)

# 2. Define function(s)
y = 2 * np.sin(2 * x)
# Optional: derivative or second function
# dy = 4 * np.cos(2 * x)

# 3. Set up plot
plt.figure(figsize=(8, 4))
plt.plot(x, y, label='y = 2·sin(2x)', color='green', linewidth=2)
# Optional: add derivative
# plt.plot(x, dy, '--', label="f'(x) = 4·cos(2x)", color='orange')

# 4. Origin-centered coordinate axes
ax = plt.gca()
ax.spines['bottom'].set_position('zero')   # x-axis at y=0
ax.spines['left'].set_position('zero')     # y-axis at x=0
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)

# 5. Optional: axis arrows
ax.plot(1, 0, ">r", transform=ax.get_yaxis_transform(), clip_on=False)  # x-arrow
ax.plot(0, 1, "^r", transform=ax.get_xaxis_transform(), clip_on=False)  # y-arrow

# 6. Labels (repositioned & resized)
ax.set_xlabel("x", fontsize=9, labelpad=0, color = 'purple')
ax.set_ylabel("y", fontsize=9, labelpad=0, color = 'purple')
ax.xaxis.set_label_coords(0.5, -0.08)
ax.yaxis.set_label_coords(-0.08, 0.5)

# 7. Remove overlapping '0' on y-axis
ax.set_yticks([tick for tick in ax.get_yticks() if tick != 0])

# 8. Customize plot
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(1.0, 1.15), fontsize=9)
plt.title("Graph of y = 2·sin(2x)", fontsize=20, pad=15, color = 'orange' )
plt.ylim(-3, 3)

# 9. Display
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style = color:#060270;>Graph Gaussian Curve(2)</h3>

# %%
#step 0(setup)
import numpy as np
import matplotlib.pyplot as plt
#step 1(defining our function)
x = np.linspace(-10,10,1000)
y = np.exp(-x**2)
#step 3(set up plot)
plt.figure(figsize = (12,6))
plt.style.use('dark_background')
plt.fill_between(x,y,color = 'royalblue', alpha = 0.35)
plt.plot(x, y, label = r"$f(x) = e^{-x^2}$",color = 'b', linewidth = 2)
#step 4(origin centered coordinate axis)
ax = plt.gca()
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_linewidth(2)
ax.spines['left'].set_linewidth(2)
#step 5(labels)
ax.set_xlabel("x-axis", fontsize = 15, labelpad = 0, color = "orange")
ax.set_ylabel("y-axis", fontsize = 15, labelpad = 0, color = "orange")
ax.xaxis.set_label_coords(0.55,0.01)
ax.yaxis.set_label_coords(0.49,0.14)
#step 6(removing overlapping zero on y axis)
ax.set_yticks([tick for tick in ax.get_yticks() if tick != 0])
#step 7 (axis arrows)
ax.plot(1,0,">y",transform = ax.get_yaxis_transform(), clip_on = False)
ax.plot(0,1,"^y",transform = ax.get_xaxis_transform(), clip_on = False)
#step 8(customize plot!!)
plt.axhline(0, color = 'gray', linewidth = 1)
plt.axvline(0, color = 'gray', linewidth = 1)
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor = (1.0,1.15),fontsize = 15)
plt.title(r"Graph"+" of "+r"$e^{-x^2}$", fontsize = 27, pad = 15, color = 'skyblue')
#step 9(display)
plt.tight_layout()
plt.show()

# %% [markdown]
# <p style="text-align:center; font-size:30px; color:mediumseagreen;">
#   <strong>Ten Steps to Matplotlib Mastery 🎯</strong>
# </p>

# %% [markdown]
# <h2 style = color:mediumseagreen;>Step 0 : <span style = color:#060270;>Core Plot Setup</span></h2>

# %%
import numpy as np #matplotlib.pyplot is the core plotting library (like a digital graph paper)

import matplotlib.pyplot as plt #numpy is helpful for creating ranges of numbers (x-values) and functions

# %% [markdown]
# <h2 style = color:mediumseagreen;>Step 1 : <span style = color:#060270;>Define Domain🧭</span></h2>

# %% [markdown]
# <p style="margin-bottom:10px;">
#   <span style="color:black;">`np.linspace` generates spaced points over a range.</span><br>
#   <span style="color:orange; font-style:italic;">Think of it like cutting a ruler into equal parts.</span>
# </p>
#
# <div style="background:#fffaf0; border-left:4px solid orange; padding:10px;">
#   <strong>🧠 Tip:</strong> Use <code>np.linspace()</code> when you want evenly spaced input values—great for smooth plots!
# </div>
#
#  for our purpose,we define domain(input of our function using such arrays)
# #### For Example,
# To define a smooth domain from -4 to 4 with 500 points:
#
# ```python
# x = np.linspace(-4, 4, 500)
# ```
# here 500 mean, "Give me 500 equally spaced values from -4 to 4.”
# <p style="margin-bottom:10px;">
# <div style = "background:#F7F5C9; border-left:4px solid yellow; padding:10px;">
#     <strong>👍rule of thumb, </strong>larger the third input smoother the curve(checkout 100 and 1000)</div>
#
# <div style = "background:#F9D6CE; border-left:4px solid red; padding:10px;">
# ⚠️ What if the domain is restricted?</div></p>
#
# imagine you're plotting regular rectangular hyperbola,but you don't want to include x = 0
# ```python
# x = np.linspace(-5, -0.1, 100)
# x2 = np.linspace(0.1, 5, 100)
# ```
# You split the domain using linspace to avoid the discontinuity!
# <p align="left">
#   <img src="https://homework.study.com/cimages/multimages/16/study2693062353680356664057.png" alt="rectangular hyperbola" width="400">
# </p>

# %% [markdown]
# <h2 style = color:mediumseagreen;>Step 2 : <span style = color:#060270;>Define Functions🧪(s)</span></h2>

# %% [markdown]
# #### it's just defining what our function of y in terms of x.
# for now,we are dealing with just single variable function
# ```python
# y = 2*np.sin(2*np.pi*x)
# ```
# We use np.sin() and np.pi from the NumPy library because they give us powerful, precise, and efficient tools for working with trigonometric functions and mathematical constants—especially when plotting or analyzing functions in Python.
# #### you can also include second or third fuction with another naming like g = ..., h =...,function = ..., banana = ...,
# ```python
# g = np.cos(2*np.pi*x)
# ```
# <div style = "background:#F9D6CE; border-left:4px solid red; padding:10px;">
#     ⚠️🎯<strong>Caution: </strong>Don't use spaces for defining functions!(like my plot = ... ❌)</div>
# <div style = "background:#ADFB8E; border-left:4px solid green; padding:10px;">
#     ✅<strong> Correct: </strong>my_plot = ... </div>
#
# #### For Example,
# <h4 style = color:orange;font-weight:bold;>Plotting 2 Graphs🌊+🌊</h4>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-4*np.pi ,4*np.pi, 1000)
y = 2*np.sin(2*x)
dy = 4*np.cos(2*x)
plt.plot(x, y, label = 'y = 2sin(2x)', color = 'g', linewidth = 1)
plt.plot(x, dy, label = 'dy = 4cos(2x)', color ='orange', linewidth = 1)
plt.axhline(0, color = 'gray', linewidth = 1)
plt.axvline(0, color = 'gray', linewidth = 1)
plt.title("Function vs. Derivative")
plt.xlabel("x")
plt.ylabel("y and f'(y)")
plt.grid(True)
plt.legend(loc='upper center', bbox_to_anchor=(1.0, 1.15))
plt.ylim(-5, 5)
ax = plt.gca()
ax.spines['bottom'].set_linewidth(1.2)
ax.spines['left'].set_linewidth(1.2)
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_xlabel("x-axis",fontsize = 7, labelpad = 0)
ax.set_ylabel("y and dy",fontsize = 7, labelpad = 0)
ax.xaxis.set_label_coords(0.57, 0.47)  # x-label: right side, slightly below x-axis
ax.yaxis.set_label_coords(0.48, 0.57)  # y-label: top side, slightly left of y-axis
ax.set_yticks([tick for tick in ax.get_yticks() if tick != 0])
# Get the current Axes
ax = plt.gca()

# Add arrowhead to x-axis (right direction)
ax.plot(1, 0, ">k", transform=ax.get_yaxis_transform(), clip_on=False)

# Add arrowhead to y-axis (upward direction)
ax.plot(0, 1, "^k", transform=ax.get_xaxis_transform(), clip_on=False)
plt.show()

# %% [markdown]
# <h2 style = color:mediumseagreen;>Step 3 : <span style = color:#060270;>Set Up Plot Canvas 🎨</span></h2>

# %% [markdown]
# <h3 style = color:purple;> 🎨 Visualizing `figsize` — How Big Is Your Canvas?</h3>
#
# The `figsize` argument in `plt.figure(figsize=(width, height))` sets the dimensions of your plot in **inches**.
# <span>Larger width → wider graph. Larger height → taller graph.</span>
# <p>
#     🔸Default-ish size <strong>(6x4 inches)</strong><br>
#    🔹Wide format <strong>(12x4 inches)</strong><br>🔸  Square format <strong>(5x5 inches)</strong><br>
#     🔹Tall format <strong>(4x8 inches)</strong></p>
# <p align="left">
#   <img src="https://apidemos.geek-docs.com/matplotlib/2024/06/12/20240606070635-3.png" alt="fig-size" width="400">
# </p>
#
#  just check out them in our real plot example plots(so you can decide what choses you)
# <h3 style = color:purple;>🔧 What plt.plot() Does</h3>
# <h4 style = color:orange;>At its core, plt.plot() draws lines (and optionally markers) between points on a 2D plane.</h4>
#
# ### 🧠 Basic Syntax
# ```python
# plt.plot(x, y, format_string, **kwargs)
# ```
# <p>
#     <span style = color:brown;>➤x: </span><span>array-like, the horizontal coordinate</span><br>
#     <span style = color:brown;>➤y: </span><span>array-like, the vertical coordinates</span><br>
#     <span style = color:brown;>➤format_string (optional): </span><span>a shortcut to define color, marker, and line style</span><br>
#     <span style = color:brown;>➤**kwargs: </span><span>keyword arguments to customize appearance</span></p>
#
# ###### <span style = color:indigo;>example</span>
# ```python
# plt.plot(x, y, label = 'y = 2sin2x', color = 'green', linewidth = 2)
# ```
# here we already get used to of x, y.
# #### <span style = color:brown;>Label🏷️: </span><span> just naming our function   (kind of <span style = color:orange;>Name tag!</span>)</span>
# and you question, what about <span style = color:blue;>C</span><span style = color:orange;>O</span><span style = color:red;>L</span><span style = color:yellow;>O</span><span style = color:indigo;>R</span><span style = color:pink;>S</span>❓<br
# <span>Just check out,</span><a href="https://matplotlib.org/stable/users/explain/colors/colors.html">Click here, if you wanna customize your plot📈 with color🌈</a>
# <p>
#     <h3 style = color:indigo;>customizing line: </h3><br>
#     <h4 style = color:orange;>color:</h4><br>
#     <span>check out various colors, and shortcuts</span><br>
#     <pre>
#     'r'   = 'red'   🔴
#     'g'   = 'green' 🟢
#     'b'   = 'blue'  🔵
#     'k'   = 'black' ⚫
#     </pre>
#     <span> 'orange'🟠, 'purple'🟣, ...</span><br>
# </p>
# <p>
#     <h4 style = color:orange;>can also include linestyle keyword(or ls for shortcut) in plt.plot():</h4><br>
#     <table style="margin-left: 0;">
#   <thead>
#     <tr>
#       <th>Line Style</th>
#       <th>Short Code</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>solid</td>
#       <td>'-'</td>
#       <td>Default solid line</td>
#     </tr>
#     <tr>
#       <td>dashed</td>
#       <td>'--'</td>
#       <td>Dashed line</td>
#     </tr>
#     <tr>
#       <td>dotted</td>
#       <td>':'</td>
#       <td>Dotted line</td>
#     </tr>
#     <tr>
#       <td>dashdot</td>
#       <td>'-.'</td>
#       <td>Dash-dot line</td>
#     </tr>
#   </tbody>
# </table>
#
# </p>
# <h4 style = color:orange;>You can vary width of line by setting linewidth to higher or lower numeric value </h4><br>
# <h3 style = color:purple;>⚡Let's plot a piece wise defined function, using the acquired knowledge⚡</h3>

# %%
#step 0: importing
import numpy as np
import matplotlib.pyplot as plt
#step 1: defining domain 
x1 = np.linspace(0, 2, 500)
x2 = np.linspace(2, 4, 200)
x3 = np.linspace(4, 6, 700)
x4 = np.linspace(6, 8, 200)
#step 2: defining our piece wise function
y1 = 2*np.sin(5*x1)
y2 = np.exp(-x2)
y3 = np.cos(10*x3)
y4 = x4 - 8
#step 3: plotting and labelling our function with customization🎨🖌️!
# try to explore extreme cases like linewidth = 0.1, ls = 10.
plt.figure(figsize=(10, 4))# wider graph, for our purpose
plt.plot(x1, y1, label = "y = 2sinx", color="blue", linewidth=3, linestyle = '--')
plt.plot(x2, y2, label = r"$y =e^{-x}$", color="orange", linewidth=4, linestyle = ':')
plt.plot(x3, y3, label = "y = cosx", color="red", linewidth=0.5, linestyle = '-')
plt.plot(x4, y4, label = "y = x - 8", color="purple", linewidth=2, linestyle = '-.')
#👉even if you skip remaining steps, these two are mandatory for plotting our function and showing label
plt.legend()
plt.show()

# %% [markdown]
# you may wonder,<span style = color:red;> how to label??</span> $e^{-x}$ (or) $\frac{1}{x^{2} + 1}$
# <h4 style = color:indigo;>Learn LaTeX!!(<span style = color:orange;>Optional</span>)</h4>
# <details><summary style = font-weight:italic;>👀 LaTeX Quick Reference (click here)</summary>
#     <h3 style = color:royalblue;>🧠 What is LaTeX?</h3>
# <p>
# LaTeX (pronounced “Lay-tech”) is a typesetting language designed for writing high-quality mathematical and scientific documents. Think of it as Markdown for mathematics—but way more expressive.<br></p>
#     <h3 style = color:royalblue;>⚙️ How to Use LaTeX in Markdown</h3>
#     <h4 style = color:green;>✅ Basic Inline Math</h4>
#     Use single dollar signs:<br>
#     This is a Gaussian:<code> $f(x) = e^{-x^2}$</code><br>
#     <strong>Rendered as: </strong>This is a Gaussian: $f(x) = e^{-x^2}$
#     <h4 style = color:green;>✅ Display(centered) Equations</h4>
#     Use double dollar signs:<br>
#     highlight important formulas!!<br>
#     In Jupyter Markdown, make sure:<br>
#     ✔️There’s an empty line above and below the $$...$$ block to avoid rendering issues.<br>
#     ✔️You’re not placing it inside bullet lists unless you're careful—it can disrupt formatting there.<br>
#     <code>$$f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}}$$</code><br>
#     <strong>Rendered as: </strong><br>
#     $$f(x) = \frac{1}{\sqrt{2\pi}} e^{-\frac{x^2}{2}}$$<br>
#     <h4 style = color:green;>🧮 Common LaTeX Elements for Your Notebook</h4>
#  <div style="border-left:4px solid royalblue; background:#f9f9f9; padding:10px;">
#     <table style="border-collapse: collapse; width: 70%; text-align: left;">
#         <thead style=background-color:#f0f0f0; >
#             <tr>
#             <th style = color:royalblue;font-weight:bold;text-align:right;padding:8px;>Use Code</th>
#             <th style = color:royalblue;font-weight:bold;text-align:right;padding:8px;>Syntax</th>
#             <th style = color:royalblue;font-weight:bold;text-align:center;padding:8px;>Output</th>
#             </tr>
#         </thead>
#         <tbody>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Superscript</td>
#                 <td style="padding: 8px;">x^2</td>
#                 <td style = text-align:center;padding:8px;>$x^2$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Subscript</td>
#                 <td style="padding: 8px;">x_0</td>
#                 <td style = text-align:center;padding:8px;>$x_0$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Fractions</td>
#                 <td style="padding: 8px;">\frac{a}{b}</td>
#                 <td style = text-align:center;padding:8px;>$\frac{a}{b}$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Greek letters</td>
#                 <td style="padding: 8px;">\alpha, \beta, \pi</td>
#                 <td style = text-align:center;padding:8px;>$\alpha, \beta, \pi$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Square root</td>
#                 <td style="padding: 8px;">\sqrt{x}</td>
#                 <td style = text-align:center;padding:8px;>$\sqrt{x}$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Derivative</td>
#                 <td style="padding: 8px;">\frac{dy}{dx}</td>
#                 <td style = text-align:center;padding:8px;>$\frac{dy}{dx}$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Integrals</td>
#                 <td style="padding: 8px;">\int-0^1 x^2 dx</td>
#                 <td style = text-align:center;padding:8px;>$\int_0^1 x^2 dx$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>Summation</td>
#                 <td style="padding: 8px;">\sum_{i=1}^n i</td>
#                 <td style = text-align:center;padding:8px;>$\sum_{i=1}^n i$</td>
#             </tr>
#             <tr>
#                 <td style = color:skyblue;padding:8px;>infinity</td>
#                 <td style="padding: 8px;">\infty</td>
#                 <td style = text-align:center;padding:8px;>$\infty$</td>
#             </tr>
#         </tbody>
#     </table>
#   </div>
# <h4 style = color:green;>📊 Using LaTeX in Matplotlib</h4>
#     Inside <code> plt.title()</code>,<code> plt.xlabel()</code>, <code>legend()</code>, etc., wrap LaTeX with<code> r"..." </code>and <code>$...$</code>:
#
# ```python
# plt.title(r"$y = 2\sin(2x)$", fontsize=16)
# plt.legend([r"$f(x) = e^{-x^2}$"])
# ```
# This tells Python: “Interpret this as a raw string containing LaTeX.”
#
# </details>

# %% [markdown]
# <h2 style = color:mediumseagreen;>Step 4 : <span style = color:#060270;>Origin-Centered Coordinate axes(<span style = color:orange;>Optional</span>)</span></h2>
